# %% [markdown]
# # Exploración — Clustering (Santiago DS)
#
# Pieza del sistema: **CLUSTERING**. Notebook de exploración sobre la base histórica.
#
# **TODOs:**
# - [ ] Cargar la base histórica.
# - [ ] EDA: distribuciones de ingreso, zona, afiliación, personas a cargo.
# - [ ] Selección de features (subconjunto del contrato de datos, sección 4).
# - [ ] Probar k y validar (silueta / codo).
# - [ ] Pasar hallazgos a `src/entrenar.py`.

# %%
# TODO: cargar datos y explorar
import pandas as pd
